# %%
import mlflow
mlflow.set_tracking_uri("mlflow/")
runs = mlflow.search_runs(experiment_names=["crypto-anomaly-detection"])
runs[["run_id","params.contamination","params.n_estimators",
      "metrics.precision","metrics.recall","metrics.f1"]].sort_values("metrics.f1", ascending=False)
